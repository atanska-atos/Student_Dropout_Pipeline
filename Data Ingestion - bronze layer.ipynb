# %%
import pandas as pd

# %%
df_raw = pd.read_csv('/Volumes/workspace/default/dropoutstudents_volume/student_dropout_dataset_v3.csv')

# %%
df_raw.to_parquet('/Volumes/workspace/default/dropoutstudents_volume/students_bronze.parquet')
